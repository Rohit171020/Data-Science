# %%
import random
outcome = ["Heads", "Tails"]
result = random.choice(outcome)
print(result)
# Out:
# Tails

# %%
favourable_outcome = 1
total_outcome = 6
probability = favourable_outcome / total_outcome
print(probability)
# Out:
# 0.16666666666666666

# %%
#conditional probability
p_study = 0.7
p_pass = 0.8
p_pass = p_study*p_pass
print(p_pass)
# Out:
# 0.5599999999999999

# %%
import numpy as np  
mean = 0
std_dev = 1
samples = np.random.normal(mean, std_dev, 1000)
print(samples)
# Out:
# [ 5.21051796e-02  2.04576223e-01 -1.02468362e+00  1.88009590e+00
#  -8.64136998e-01 -2.01497395e-01 -1.93581532e+00  8.14180581e-01
#   1.04055674e+00 -1.42050864e+00 -2.02574206e+00  1.46770308e+00
#  -5.17574888e-01  5.09536538e-01 -1.02791179e+00  2.65806028e-01
#   1.82092919e+00 -6.10989308e-01  2.61142316e+00 -5.44119771e-01
#   2.09051463e+00 -9.39009630e-02 -1.58259623e+00  2.04453417e+00
#   7.40151609e-01 -1.49934324e+00 -1.36689830e+00  1.69437981e+00
#   6.39727601e-01 -3.66182985e-01 -3.64725166e-01 -1.01282015e+00
#   1.16799625e+00 -4.58585946e-01 -1.59285276e+00  1.01903944e+00
#  -1.55327476e-01  1.89145940e+00  4.11385220e-01  1.97897905e+00
#   1.17630454e+00  3.79143640e-01 -7.85927835e-01 -1.07111274e-01
#   1.58019861e+00  1.42039350e-01  5.13521133e-01 -1.89262271e+00
#   2.93847015e-01  3.15310095e-01  7.17576878e-01 -5.52499897e-01
#  -1.92173008e-01  1.25405559e+00 -4.88655539e-01 -1.61155161e-01
# ...

# %%
prime_numbers = {2, 3, 5}
total_numbers = {1, 2, 3, 4, 5, 6}

prob = len(prime_numbers) / len(total_numbers)
print(f"Probability of rolling a prime number: {prob:.2f}")
